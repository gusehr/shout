# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import unicodedata
import re

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# pagamentos 2017
ds1701 = pd.read_csv("../datasets/pagamentos/201701_Transferencias.csv", sep='\t', encoding='latin1')
ds1702 = pd.read_csv("../datasets/pagamentos/201702_Transferencias.csv", sep='\t', encoding='latin1')
ds1703 = pd.read_csv("../datasets/pagamentos/201703_Transferencias.csv", sep='\t', encoding='latin1')
ds1704 = pd.read_csv("../datasets/pagamentos/201704_Transferencias.csv", sep='\t', encoding='latin1')
ds1705 = pd.read_csv("../datasets/pagamentos/201705_Transferencias.csv", sep='\t', encoding='latin1')
ds1706 = pd.read_csv("../datasets/pagamentos/201706_Transferencias.csv", sep='\t', encoding='latin1')
ds1707 = pd.read_csv("../datasets/pagamentos/201707_Transferencias.csv", sep='\t', encoding='latin1')
ds1708 = pd.read_csv("../datasets/pagamentos/201708_Transferencias.csv", sep='\t', encoding='latin1')
ds1709 = pd.read_csv("../datasets/pagamentos/201709_Transferencias.csv", sep='\t', encoding='latin1')
ds1710 = pd.read_csv("../datasets/pagamentos/201710_Transferencias.csv", sep='\t', encoding='latin1')
ds1711 = pd.read_csv("../datasets/pagamentos/201711_Transferencias.csv", sep='\t', encoding='latin1')
ds1712 = pd.read_csv("../datasets/pagamentos/201712_Transferencias.csv", sep='\t', encoding='latin1')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,9,11,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# pagamentos 2016
ds1601 = pd.read_csv("../datasets/pagamentos/201601_Transferencias.csv", sep='\t', encoding='latin1')
ds1602 = pd.read_csv("../datasets/pagamentos/201602_Transferencias.csv", sep='\t', encoding='latin1')
ds1603 = pd.read_csv("../datasets/pagamentos/201603_Transferencias.csv", sep='\t', encoding='latin1')
ds1604 = pd.read_csv("../datasets/pagamentos/201604_Transferencias.csv", sep='\t', encoding='latin1')
ds1605 = pd.read_csv("../datasets/pagamentos/201605_Transferencias.csv", sep='\t', encoding='latin1')
ds1606 = pd.read_csv("../datasets/pagamentos/201606_Transferencias.csv", sep='\t', encoding='latin1')
ds1607 = pd.read_csv("../datasets/pagamentos/201607_Transferencias.csv", sep='\t', encoding='latin1')
ds1608 = pd.read_csv("../datasets/pagamentos/201608_Transferencias.csv", sep='\t', encoding='latin1')
ds1609 = pd.read_csv("../datasets/pagamentos/201609_Transferencias.csv", sep='\t', encoding='latin1')
ds1610 = pd.read_csv("../datasets/pagamentos/201610_Transferencias.csv", sep='\t', encoding='latin1')
ds1611 = pd.read_csv("../datasets/pagamentos/201611_Transferencias.csv", sep='\t', encoding='latin1')
ds1612 = pd.read_csv("../datasets/pagamentos/201612_Transferencias.csv", sep='\t', encoding='latin1')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,9,12,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# pagamentos 2015
ds1501 = pd.read_csv("../datasets/pagamentos/201501_Transferencias.csv", sep='\t', encoding='latin1')
ds1502 = pd.read_csv("../datasets/pagamentos/201502_Transferencias.csv", sep='\t', encoding='latin1')
ds1503 = pd.read_csv("../datasets/pagamentos/201503_Transferencias.csv", sep='\t', encoding='latin1')
ds1504 = pd.read_csv("../datasets/pagamentos/201504_Transferencias.csv", sep='\t', encoding='latin1')
ds1505 = pd.read_csv("../datasets/pagamentos/201505_Transferencias.csv", sep='\t', encoding='latin1')
ds1506 = pd.read_csv("../datasets/pagamentos/201506_Transferencias.csv", sep='\t', encoding='latin1')
ds1507 = pd.read_csv("../datasets/pagamentos/201507_Transferencias.csv", sep='\t', encoding='latin1')
ds1508 = pd.read_csv("../datasets/pagamentos/201508_Transferencias.csv", sep='\t', encoding='latin1')
ds1509 = pd.read_csv("../datasets/pagamentos/201509_Transferencias.csv", sep='\t', encoding='latin1')
ds1510 = pd.read_csv("../datasets/pagamentos/201510_Transferencias.csv", sep='\t', encoding='latin1')
ds1511 = pd.read_csv("../datasets/pagamentos/201511_Transferencias.csv", sep='\t', encoding='latin1')
ds1512 = pd.read_csv("../datasets/pagamentos/201512_Transferencias.csv", sep='\t', encoding='latin1')

# %%
# pagamentos 2014
ds1401 = pd.read_csv("../datasets/pagamentos/201401_Transferencias.csv", sep='\t', encoding='latin1')
ds1402 = pd.read_csv("../datasets/pagamentos/201402_Transferencias.csv", sep='\t', encoding='latin1')
ds1403 = pd.read_csv("../datasets/pagamentos/201403_Transferencias.csv", sep='\t', encoding='latin1')
ds1404 = pd.read_csv("../datasets/pagamentos/201404_Transferencias.csv", sep='\t', encoding='latin1')
ds1405 = pd.read_csv("../datasets/pagamentos/201405_Transferencias.csv", sep='\t', encoding='latin1')
ds1406 = pd.read_csv("../datasets/pagamentos/201406_Transferencias.csv", sep='\t', encoding='latin1')
ds1407 = pd.read_csv("../datasets/pagamentos/201407_Transferencias.csv", sep='\t', encoding='latin1')
ds1408 = pd.read_csv("../datasets/pagamentos/201408_Transferencias.csv", sep='\t', encoding='latin1')
ds1409 = pd.read_csv("../datasets/pagamentos/201409_Transferencias.csv", sep='\t', encoding='latin1')
ds1410 = pd.read_csv("../datasets/pagamentos/201410_Transferencias.csv", sep='\t', encoding='latin1')
ds1411 = pd.read_csv("../datasets/pagamentos/201411_Transferencias.csv", sep='\t', encoding='latin1')
ds1412 = pd.read_csv("../datasets/pagamentos/201412_Transferencias.csv", sep='\t', encoding='latin1')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# pagamentos 2013
ds1301 = pd.read_csv("../datasets/pagamentos/201301_Transferencias.csv", sep='\t', encoding='latin1')
ds1302 = pd.read_csv("../datasets/pagamentos/201302_Transferencias.csv", sep='\t', encoding='latin1')
ds1303 = pd.read_csv("../datasets/pagamentos/201303_Transferencias.csv", sep='\t', encoding='latin1')
ds1304 = pd.read_csv("../datasets/pagamentos/201304_Transferencias.csv", sep='\t', encoding='latin1')
ds1305 = pd.read_csv("../datasets/pagamentos/201305_Transferencias.csv", sep='\t', encoding='latin1')
ds1306 = pd.read_csv("../datasets/pagamentos/201306_Transferencias.csv", sep='\t', encoding='latin1')
ds1307 = pd.read_csv("../datasets/pagamentos/201307_Transferencias.csv", sep='\t', encoding='latin1')
ds1308 = pd.read_csv("../datasets/pagamentos/201308_Transferencias.csv", sep='\t', encoding='latin1')
ds1309 = pd.read_csv("../datasets/pagamentos/201309_Transferencias.csv", sep='\t', encoding='latin1')
ds1310 = pd.read_csv("../datasets/pagamentos/201310_Transferencias.csv", sep='\t', encoding='latin1')
ds1311 = pd.read_csv("../datasets/pagamentos/201311_Transferencias.csv", sep='\t', encoding='latin1')
ds1312 = pd.read_csv("../datasets/pagamentos/201312_Transferencias.csv", sep='\t', encoding='latin1')

# %%
# pagamentos 2012
ds1201 = pd.read_csv("../datasets/pagamentos/201201_Transferencias.csv", sep='\t', encoding='latin1')
ds1202 = pd.read_csv("../datasets/pagamentos/201202_Transferencias.csv", sep='\t', encoding='latin1')
ds1203 = pd.read_csv("../datasets/pagamentos/201203_Transferencias.csv", sep='\t', encoding='latin1')
ds1204 = pd.read_csv("../datasets/pagamentos/201204_Transferencias.csv", sep='\t', encoding='latin1')
ds1205 = pd.read_csv("../datasets/pagamentos/201205_Transferencias.csv", sep='\t', encoding='latin1')
ds1206 = pd.read_csv("../datasets/pagamentos/201206_Transferencias.csv", sep='\t', encoding='latin1')
ds1207 = pd.read_csv("../datasets/pagamentos/201207_Transferencias.csv", sep='\t', encoding='latin1')
ds1208 = pd.read_csv("../datasets/pagamentos/201208_Transferencias.csv", sep='\t', encoding='latin1')
ds1209 = pd.read_csv("../datasets/pagamentos/201209_Transferencias.csv", sep='\t', encoding='latin1')
ds1210 = pd.read_csv("../datasets/pagamentos/201210_Transferencias.csv", sep='\t', encoding='latin1')
ds1211 = pd.read_csv("../datasets/pagamentos/201211_Transferencias.csv", sep='\t', encoding='latin1')
ds1212 = pd.read_csv("../datasets/pagamentos/201212_Transferencias.csv", sep='\t', encoding='latin1')

# %%
# pagamentos 2011
ds1101 = pd.read_csv("../datasets/pagamentos/201101_Transferencias.csv", sep='\t', encoding='latin1')
ds1102 = pd.read_csv("../datasets/pagamentos/201102_Transferencias.csv", sep='\t', encoding='latin1')
ds1103 = pd.read_csv("../datasets/pagamentos/201103_Transferencias.csv", sep='\t', encoding='latin1')
ds1104 = pd.read_csv("../datasets/pagamentos/201104_Transferencias.csv", sep='\t', encoding='latin1')
ds1105 = pd.read_csv("../datasets/pagamentos/201105_Transferencias.csv", sep='\t', encoding='latin1')
ds1106 = pd.read_csv("../datasets/pagamentos/201106_Transferencias.csv", sep='\t', encoding='latin1')
ds1107 = pd.read_csv("../datasets/pagamentos/201107_Transferencias.csv", sep='\t', encoding='latin1')
ds1108 = pd.read_csv("../datasets/pagamentos/201108_Transferencias.csv", sep='\t', encoding='latin1')
ds1109 = pd.read_csv("../datasets/pagamentos/201109_Transferencias.csv", sep='\t', encoding='latin1')
ds1110 = pd.read_csv("../datasets/pagamentos/201110_Transferencias.csv", sep='\t', encoding='latin1')
ds1111 = pd.read_csv("../datasets/pagamentos/201111_Transferencias.csv", sep='\t', encoding='latin1')
ds1112 = pd.read_csv("../datasets/pagamentos/201112_Transferencias.csv", sep='\t', encoding='latin1')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pagamentos = pd.concat( \
    [ds1701, ds1702, ds1703, ds1704, ds1705, ds1706, \
     ds1707, ds1708, ds1709, ds1710, ds1711, ds1712, \
     ds1601, ds1602, ds1603, ds1604, ds1605, ds1606, \
     ds1607, ds1608, ds1609, ds1610, ds1611, ds1612, \
     ds1501, ds1502, ds1503, ds1504, ds1505, ds1506, \
     ds1507, ds1508, ds1509, ds1510, ds1511, ds1512, \
     ds1401, ds1402, ds1403, ds1404, ds1405, ds1406, \
     ds1407, ds1408, ds1409, ds1410, ds1411, ds1412, \
     ds1301, ds1302, ds1303, ds1304, ds1305, ds1306, \
     ds1307, ds1308, ds1309, ds1310, ds1311, ds1312, \
     ds1201, ds1202, ds1203, ds1204, ds1205, ds1206, \
     ds1207, ds1208, ds1209, ds1210, ds1211, ds1212, \
     ds1101, ds1102, ds1103, ds1104, ds1105, ds1106, \
     ds1107, ds1108, ds1109, ds1110, ds1111, ds1112])

pagamentos.count()
# Out:
# Sigla Unidade Federação    16716693
# Codigo SIAFI Municipio     16717054
# Nome Municipio             16717054
# Codigo Funcao              16716693
# Nome Funcao                16716693
# Codigo Sub Funcao          16716693
# Nome Sub Funcao            16716693
# Codigo Programa            16716693
# Nome Programa              16716693
# Codigo Acao                16716639
# Nome Acao                  16716693
# Linguagem Cidadã           14043679
# Codigo Favorecido          16716693
# Nome Favorecido            16716467
# Fonte-Finalidade           16716602
# Modalidade Aplicação       11269223
# Número Convênio             5568736
# Valor Parcela              16716332
# dtype: int64

# %%
empresas = pd.read_csv("../datasets/sancoes/20180331_CEIS.csv", sep=';', encoding='latin1')
empresas.count()
# Out:
# Tipo de Pessoa                              12537
# CPF ou CNPJ do Sancionado                   12537
# Nome Informado pelo Órgão Sancionador       12537
# Razão Social - Cadastro Receita             12531
# Nome Fantasia - Cadastro Receita             4528
# Número do processo                          12537
# Tipo Sanção                                 12537
# Data Início Sanção                          12537
# Data Final Sanção                           11384
# Órgão Sancionador                           12536
# UF Órgão Sancionador                        11547
# Origem Informações                          12537
# Data Origem Informações                     12537
# Data Publicação                              6166
# Publicação                                   5076
# Detalhamento                                 2181
# Abrangência definida em decisão judicial     1243
# Fundamentação Legal                         12147
# Descrição da Fundamentação Legal            12147
# ...

# %%
dataset = pd.merge(pagamentos, empresas \
    , how='inner' \
    , left_on=u"Codigo Favorecido" \
    , right_on=u"CPF ou CNPJ do Sancionado")

# %%
dataset.count()
# Out:
# Sigla Unidade Federação                     2790
# Codigo SIAFI Municipio                      2790
# Nome Municipio                              2790
# Codigo Funcao                               2790
# Nome Funcao                                 2790
# Codigo Sub Funcao                           2790
# Nome Sub Funcao                             2790
# Codigo Programa                             2790
# Nome Programa                               2790
# Codigo Acao                                 2790
# Nome Acao                                   2790
# Linguagem Cidadã                            1829
# Codigo Favorecido                           2790
# Nome Favorecido                             2790
# Fonte-Finalidade                            2790
# Modalidade Aplicação                        1482
# Número Convênio                              575
# Valor Parcela                               2790
# Tipo de Pessoa                              2790
# ...

# %%
dataset
# Out:
#      Sigla Unidade Federação Codigo SIAFI Municipio  \
# 0                         RO                     15
# 1                         RO                     15
# 2                         RO                     15
# 3                         RO                     15
# 4                         RO                     15
# 5                         RO                     15
# 6                         RO                     15
# 7                         RO                     15
# 8                         RO                     15
# 9                         RO                     15
# 10                        RO                     15
# 11                        RO                   0015
# 12                        RO                     15
# 13                        RO                     15
# 14                        RO                     15
# 15                        RO                     15
# 16                        RO                     15
# ...

# %%
dataset.to_csv("../datasets/pagamentos/payments_merge.tmp", sep="\t", encoding="latin1")

# %%
temp = pd.read_csv("../datasets/pagamentos/payments_merge.csv", sep="\t", encoding="latin1")
temp.count()
# Out:
# Unnamed: 0                                  2790
# Sigla Unidade Federação                     2790
# Codigo SIAFI Municipio                      2790
# Nome Municipio                              2790
# Codigo Funcao                               2790
# Nome Funcao                                 2790
# Codigo Sub Funcao                           2790
# Nome Sub Funcao                             2790
# Codigo Programa                             2790
# Nome Programa                               2790
# Codigo Acao                                 2790
# Nome Acao                                   2790
# Linguagem Cidadã                            1829
# Codigo Favorecido                           2790
# Nome Favorecido                             2790
# Fonte-Finalidade                            2790
# Modalidade Aplicação                        1482
# Número Convênio                              575
# Valor Parcela                               2790
# ...

# %%
temp
# Out:
#       Unnamed: 0 Sigla Unidade Federação  Codigo SIAFI Municipio  \
# 0              0                      RO                      15
# 1              1                      RO                      15
# 2              2                      RO                      15
# 3              3                      RO                      15
# 4              4                      RO                      15
# 5              5                      RO                      15
# 6              6                      RO                      15
# 7              7                      RO                      15
# 8              8                      RO                      15
# 9              9                      RO                      15
# 10            10                      RO                      15
# 11            11                      RO                      15
# 12            12                      RO                      15
# ...
